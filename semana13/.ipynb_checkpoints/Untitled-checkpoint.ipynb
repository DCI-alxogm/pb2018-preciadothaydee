# %%
import matplotlib.pyplot as plt 
import numpy as np 
# %matplotlib inline

# %%
x=np.random.rand(12) 
y=np.random.rand(12)
plt.plot(x,y,'p')
p=np.array([x,y]) 
print (p)
# Out:
# [[0.97369925 0.82985783 0.53510901 0.38622445 0.85993226 0.69312861
#   0.010734   0.94174249 0.9291766  0.36228881 0.18585569 0.01866983]
#  [0.73115534 0.450286   0.4785755  0.21559149 0.87502236 0.27507255
#   0.75929475 0.38335653 0.74202503 0.17972449 0.03617847 0.92681461]]

# %%
for s in range (12):
    u=p[0,s]
    l=p[1,s]
    plt.scatter(u,l, color='pink') 
    for c in range(0,360,30):
            y=((0.1)*np.sin(c))
            x=((0.1)*np.cos(c))
            plt.scatter(x+u,y+l,color='blue')
